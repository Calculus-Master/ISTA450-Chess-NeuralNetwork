# %%
# Imports
from chess import WHITE, BLACK, PAWN, KNIGHT, BISHOP, ROOK, QUEEN, Board, \
    Color, Piece
from chess.pgn import read_game, GameNode
import pandas as pd
from pandas import DataFrame

# %%
# Setup empty dataframe
data_headers = [
    "White Pawns", "White Knights", "White Bishops", "White Rooks", "White Queens",
    "Black Pawns", "Black Knights", "Black Bishops", "Black Rooks", "Black Queens",
    "Result_W", "Result_B", "Result_S"]
data = pd.DataFrame(columns=data_headers, dtype=int)
data.head()
# Out:
# Empty DataFrame
# Columns: [White Pawns, White Knights, White Bishops, White Rooks, White Queens, Black Pawns, Black Knights, Black Bishops, Black Rooks, Black Queens, Result_W, Result_B, Result_S]
# Index: []

# %%
# Logic Setup
colors = [WHITE, BLACK]
pieces = [PAWN, KNIGHT, BISHOP, ROOK, QUEEN]
piece_names = {
    PAWN: "Pawn",
    KNIGHT: "Knight",
    BISHOP: "Bishop",
    ROOK: "Rook",
    QUEEN: "Queen"
}

def is_stalemate(node: GameNode) -> bool:
    return node.game().headers["Result"] == "1/2-1/2"

def num_pieces(board: Board, color: Color, piece: int) -> int:
    return len(board.pieces(piece, color))

def column_name(color: Color, piece: int) -> str:
    c = "White" if color == WHITE else "Black"
    p = (piece_names[piece] + "s")
    return c + " " + p

def get_game_result(node: GameNode) -> str:
    return node.game().headers["Result"]

def load_game_into_df(df: DataFrame, game_node: GameNode) -> DataFrame:
    while not game_node.is_end():
        series = pd.Series(index=data_headers, dtype=int)
        
        board = game_node.board()
        for c in colors:
            for p in pieces:
                series[column_name(c, p)] = num_pieces(board, c, p)
        
        res = get_game_result(game_node)
        if res == "1-0":
            series["Result_W"] = 1
            series["Result_B"] = 0
            series["Result_S"] = 0
        elif res == "0-1":
            series["Result_W"] = 0
            series["Result_B"] = 1
            series["Result_S"] = 0
        elif res == "1/2-1/2":
            series["Result_W"] = 0
            series["Result_B"] = 0
            series["Result_S"] = 1
            
        df = pd.concat([df, pd.DataFrame(series).T], ignore_index=True).astype(int)
        
        game_node = game_node.next()
        
    return df

# %%
# Read the PGN DB
chess_db = open("data/AJ-OTB-PGN-001.pgn", encoding="utf-8")

# Set data limits
WINS = 700 # Number of wins for each side
STALEMATES = 700 # Number of stalemates

# Load data into dataframe
num_w_wins = 0
num_b_wins = 0
num_stalemates = 0
while num_w_wins < WINS or num_b_wins < WINS or num_stalemates < STALEMATES:
    game = read_game(chess_db)
    
    res = get_game_result(game)
    if res == "1-0":
        if num_w_wins > WINS:
            continue
        num_w_wins += 1
    elif res == "0-1":
        if num_b_wins > WINS:
            continue
        num_b_wins += 1
    elif res == "1/2-1/2":
        if num_stalemates > STALEMATES:
            continue
        num_stalemates += 1
    else:
        continue
        
    data = load_game_into_df(data, game)
data
# Out:
#         White Pawns  White Knights  White Bishops  White Rooks  White Queens  \
# 0                 8              2              2            2             1
# 1                 8              2              2            2             1
# 2                 8              2              2            2             1
# 3                 8              2              2            2             1
# 4                 7              2              2            2             1
# ...             ...            ...            ...          ...           ...
# 177334            6              1              1            1             0
# 177335            6              1              1            1             0
# 177336            6              1              1            1             0
# 177337            6              1              1            1             0
# 177338            6              1              1            1             0
#
#         Black Pawns  Black Knights  Black Bishops  Black Rooks  Black Queens  \
# 0                 8              2              2            2             1
# 1                 8              2              2            2             1
# 2                 8              2              2            2             1
# 3                 8              2              2            2             1
# 4                 8              2              2            2             1
# ...             ...            ...            ...          ...           ...
# 177334            7              1              1            0             1
# 177335            7              1              1            0             1
# 177336            7              1              1            0             1
# 177337            7              1              1            0             1
# 177338            7              1              1            0             1
#
#         Result_W  Result_B  Result_S
# 0              0         0         1
# 1              0         0         1
# 2              0         0         1
# 3              0         0         1
# 4              0         0         1
# ...          ...       ...       ...
# 177334         0         1         0
# 177335         0         1         0
# 177336         0         1         0
# 177337         0         1         0
# 177338         0         1         0
#
# [177339 rows x 13 columns]

# %%
path = "data/chess_data_output-110524.csv"
data.to_csv(path, index=False)

# %%
path = "data/chess_data_output-110524.csv"
data = pd.read_csv(path)

# %%
# Checking all the game states
states = []
for i in range(10000):
    game = read_game(chess_db)
    r = game.headers["Result"]
    
    if not r in states:
        states.append(r)
    if r == "*":
        print(game.headers)
states
# Out:
# Headers(Event='Serbian Championship 2023', Site='Senta', Date='2023.06.12', Round='7.4', White='Ljepic, Andrej', Black='Indjic, Aleksandar', Result='*', ECO='A87', WhiteElo='2207', BlackElo='2613', PlyCount='45', EventDate='2023.06.04', EventType='tourn', EventCountry='SRB', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Serbian Championship 2023', Site='Senta', Date='2023.06.12', Round='7.5', White='Markus, Robert', Black='Lajthajm, Borko', Result='*', ECO='B51', WhiteElo='2582', BlackElo='2341', PlyCount='52', EventDate='2023.06.04', EventType='tourn', EventCountry='SRB', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='VII SESC Caioba Open 2023', Site='Matinhos', Date='2023.06.19', Round='1.8', White='Luz, Jhonatan Rodrigues D', Black='Santiago, Yago De Moura', Result='*', ECO='D02', WhiteElo='1775', BlackElo='2481', PlyCount='111', EventDate='2023.06.17', EventType='swiss', EventCountry='BRA', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='9th Cesme Open 2023', Site='Cesme', Date='2023.06.19', Round='1.33', White='Adiguzel, Onur', Black='Bayindir, Kuzey', Result='*', ECO='B50', WhiteElo='1447', BlackElo='1588', PlyCount='66', EventDate='2023.06.19', EventType='swiss', EventCountry='TUR', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Ramat Gan Masters Spring-A 2023', Site='Ramat Gan', Date='2023.06.05', Round='5.13', White='Goz, Shachar', Black='Vaisman, Felix', Result='*', WhiteElo='1731', BlackElo='2111', PlyCount='6', EventDate='2023.04.28', EventType='swiss', EventCountry='ISR', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Polish Youth 1st League 2023', Site='Lublin', Date='2023.06.16', Round='5.44', White='Karut, Kacper', Black='Grzebieniowski, Michal', Result='*', ECO='A43', WhiteElo='1954', BlackElo='1603', PlyCount='32', EventDate='2023.06.13', EventType='team-tourn', EventCountry='POL', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Polish Youth 1st League 2023', Site='Lublin', Date='2023.06.16', Round='5.46', White='Tim, Wojciech', Black='Modzelan, Wojciech', Result='*', ECO='B92', WhiteElo='1316', BlackElo='1091', PlyCount='25', EventDate='2023.06.13', EventType='team-tourn', EventCountry='POL', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Hungarian-ch U10-U16-U18 Girls 2023', Site='Buek', Date='2023.06.19', Round='1.1', White='Buri, Petra Zsuzsanna', Black='Buri, Kata', Result='*', ECO='B28', WhiteElo='1921', BlackElo='1877', PlyCount='42', EventDate='2023.06.17', EventCountry='HUN', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Hungarian-ch U10-U16-U18 Girls 2023', Site='Buek', Date='2023.06.19', Round='1.2', White='Farkas, Boglarka', Black='Demeter, Dorina', Result='*', ECO='C44', WhiteElo='1599', BlackElo='2183', PlyCount='78', EventDate='2023.06.17', EventCountry='HUN', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Hungarian-ch U10-U16-U18 Girls 2023', Site='Buek', Date='2023.06.19', Round='1.3', White='Nyuli, Leila', Black='Kurai, Luca', Result='*', ECO='A48', WhiteElo='1384', BlackElo='1049', PlyCount='29', EventDate='2023.06.17', EventCountry='HUN', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='9th Cesme Open 2023', Site='Cesme', Date='2023.06.25', Round='9.22', White='Aliyev, Elnur', Black='Ozdemir, Serhan Berat', Result='*', WhiteElo='2056', BlackElo='2223', PlyCount='1', EventDate='2023.06.19', EventType='swiss', EventCountry='TUR', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Hungarian-ch U16-U18 2023', Site='Buek', Date='2023.06.20', Round='2.1', White='Herpai, Jozsef Matyas', Black='Bodrogi, Bendeguz', Result='*', ECO='A36', WhiteElo='2147', BlackElo='2113', PlyCount='40', EventDate='2023.06.17', EventCountry='HUN', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Hungarian-ch U16-U18 2023', Site='Buek', Date='2023.06.20', Round='2.2', White='Vancsisin, Mark', Black='Kolimar, Kristof Pal', Result='*', ECO='D30', WhiteElo='1831', BlackElo='2310', PlyCount='45', EventDate='2023.06.17', EventCountry='HUN', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Hungarian-ch U16-U18 2023', Site='Buek', Date='2023.06.20', Round='2.3', White='Gathi, Donat', Black='Apro, Barnabas', Result='*', ECO='A04', WhiteElo='2005', BlackElo='1994', PlyCount='42', EventDate='2023.06.17', EventCountry='HUN', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Hungarian-ch U16-U18 2023', Site='Buek', Date='2023.06.20', Round='2.4', White='Turcsanyi, Vince Gergo', Black='Palczert, Matyas', Result='*', ECO='B50', WhiteElo='2234', BlackElo='2328', PlyCount='36', EventDate='2023.06.17', EventCountry='HUN', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Hungarian-ch U16-U18 2023', Site='Buek', Date='2023.06.20', Round='2.5', White='Jaro, Benjamin', Black='Szabo, Abel', Result='*', ECO='B12', WhiteElo='2006', BlackElo='2207', PlyCount='38', EventDate='2023.06.17', EventCountry='HUN', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Hungarian-ch U16-U18 2023', Site='Buek', Date='2023.06.20', Round='2.7', White='Farkas, Otto Jr.', Black='Juhasz, Agoston', Result='*', ECO='B53', WhiteElo='2051', BlackElo='2265', PlyCount='34', EventDate='2023.06.17', EventCountry='HUN', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Hungarian-ch U16-U18 2023', Site='Buek', Date='2023.06.20', Round='2.8', White='Pasztor, Balazs', Black='Daroczi, Donat', Result='*', ECO='A17', WhiteElo='2393', BlackElo='2143', PlyCount='43', EventDate='2023.06.17', EventCountry='HUN', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='8th NBP Open-A 2023', Site='Bydgoszcz', Date='2023.06.28', Round='5.11', White='Pajeken, Jakob Leon', Black='Kacprzak, Kacper', Result='*', ECO='A00', WhiteElo='2436', BlackElo='2228', PlyCount='1', EventDate='2023.06.23', EventType='swiss', EventCountry='POL', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Sportland NRW Cup 2023', Site='Dortmund', Date='2023.06.24', Round='1.1', White='De Winter, Arthur', Black='Petrovsky, Vadim', Result='*', ECO='B90', WhiteElo='2378', BlackElo='1364', PlyCount='45', EventDate='2023.06.24', EventType='tourn', EventCountry='GER', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='IRT Fiestas Sabaneta Open 2023', Site='Sabaneta Antioquia', Date='2023.07.02', Round='7.10', White='Ramos Ariza, Juan Manuel', Black='Carrillo Montes, Isabela', Result='*', ECO='B01', WhiteElo='1996', BlackElo='1319', PlyCount='16', EventDate='2023.06.25', EventType='swiss', EventCountry='COL', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='IRT Fiestas Sabaneta Open 2023', Site='Sabaneta Antioquia', Date='2023.07.03', Round='7.10', White='Alvarez, Juan P', Black='Valle, Leiner Efrain', Result='*', ECO='B01', WhiteElo='1952', BlackElo='2120', PlyCount='74', EventDate='2023.06.25', EventType='swiss', EventCountry='COL', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='IRT Fiestas Sabaneta Open 2023', Site='Sabaneta Antioquia', Date='2023.07.02', Round='7.11', White='Betancur Alvarez, Sara Maria', Black='Kostov, Alex', Result='*', ECO='C78', WhiteElo='1314', BlackElo='1989', PlyCount='34', EventDate='2023.06.25', EventType='swiss', EventCountry='COL', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='IRT Fiestas Sabaneta Open 2023', Site='Sabaneta Antioquia', Date='2023.07.02', Round='7.12', White='Vallejo, Humberto', Black='Almanza Montoya, Joseph', Result='*', ECO='B04', WhiteElo='1988', BlackElo='1230', PlyCount='30', EventDate='2023.06.25', EventType='swiss', EventCountry='COL', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='8th NBP Open-A 2023', Site='Bydgoszcz', Date='2023.07.02', Round='9.32', White='Neuhoff, Laertes', Black='Niharika Challa', Result='*', ECO='B00', WhiteElo='2065', BlackElo='2058', PlyCount='1', EventDate='2023.06.23', EventType='swiss', EventCountry='POL', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Italian Youth Championship 2023', Site='Tarvisio', Date='2023.07.03', Round='2.7', White='Trevisan, Stefano', Black='Rotondaro, Alberto', Result='*', ECO='B33', WhiteElo='1842', BlackElo='2219', PlyCount='28', EventDate='2023.07.02', EventType='swiss', EventCountry='ITA', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Italian Youth Championship 2023', Site='Tarvisio', Date='2023.07.05', Round='4.4', White='Trevisan, Stefano', Black='Clerici, Alessandro Maria', Result='*', ECO='B42', WhiteElo='1842', BlackElo='1067', PlyCount='27', EventDate='2023.07.02', EventType='swiss', EventCountry='ITA', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Israeli Womens League 2023', Site='Ramat Gan', Date='2023.07.06', Round='1.10', White='Doluhanova, Evgeniya', Black='Kluchik, Julia', Result='*', WhiteElo='2278', BlackElo='1936', PlyCount='1', EventDate='2023.07.03', EventType='team-tourn', EventCountry='ISR', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Israeli Womens League 2023', Site='Ramat Gan', Date='2023.07.06', Round='1.12', White='Kosich, Lesia', Black='Halfon, Leora', Result='*', WhiteElo='1648', PlyCount='2', EventDate='2023.07.03', EventType='team-tourn', EventCountry='ISR', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Israeli Womens League 2023', Site='Ramat Gan', Date='2023.07.06', Round='1.14', White='Khairova, Evelina', Black='Federovski, Adi', Result='*', WhiteElo='1401', BlackElo='1927', PlyCount='6', EventDate='2023.07.03', EventType='team-tourn', EventCountry='ISR', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Israeli Womens League 2023', Site='Ramat Gan', Date='2023.07.06', Round='1.16', White='Shefer, Alona', Black='Lapushnian, Maya', Result='*', WhiteElo='1220', BlackElo='1585', PlyCount='5', EventDate='2023.07.03', EventType='team-tourn', EventCountry='ISR', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Turkish Ikinci Ligi 2023', Site='Denizli', Date='2023.07.09', Round='1', White='Yilmaz, Cumhur', Black='Unlu, Ahmet Berkin', Result='*', ECO='D03', WhiteElo='1721', BlackElo='1815', PlyCount='39', EventDate='2023.07.07', EventCountry='TUR', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Ceske Budejovice Open-B 2023', Site='Ceske Budejovice', Date='2023.07.07', Round='6.7', White='Matlocha, Lubomir', Black='Cipera, Josef', Result='*', ECO='E72', WhiteElo='1660', BlackElo='1539', PlyCount='90', EventDate='2023.07.01', EventType='swiss', EventCountry='CZE', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Aimchess-Rapid-Div-I 2023', Site='Online', Date='2023.07.11', Round='2.1', White='Caruana, Fabiano', Black='Carlsen, Magnus', Result='*', ECO='B48', WhiteElo='2782', BlackElo='2835', PlyCount='37', EventDate='2023.07.10', EventType='k.o.', EventCountry='NET', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Aimchess-Rapid-Div-I 2023', Site='Online', Date='2023.07.12', Round='52.1', White='Caruana, Fabiano', Black='So, Wesley', Result='*', ECO='C54', WhiteElo='2782', BlackElo='2769', PlyCount='35', EventDate='2023.07.10', EventType='k.o.', EventCountry='NET', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Championnat IDF 2023', Site='Paris', Date='2023.07.11', Round='1.2', White='Bogner, Sebastian', Black='Rodriguez, Adrien', Result='*', ECO='A17', WhiteElo='2533', BlackElo='2300', PlyCount='13', EventDate='2023.07.10', EventType='swiss', EventCountry='FRA', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Championnat IDF 2023', Site='Paris', Date='2023.07.11', Round='1.5', White='Senthil Maran K', Black='Defromont, Benjamin', Result='*', ECO='E01', WhiteElo='2287', BlackElo='2445', PlyCount='54', EventDate='2023.07.10', EventType='swiss', EventCountry='FRA', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Championnat IDF 2023', Site='Paris', Date='2023.07.11', Round='1.8', White='Harshavardhan G B', Black='Andersen, Gunnar', Result='*', WhiteElo='2405', BlackElo='2279', PlyCount='1', EventDate='2023.07.10', EventType='swiss', EventCountry='FRA', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Championnat IDF 2023', Site='Paris', Date='2023.07.11', Round='1.11', White='Mekhane, Adam', Black='Di Nicolantonio, Lucas', Result='*', ECO='B13', WhiteElo='2269', BlackElo='2374', PlyCount='24', EventDate='2023.07.10', EventType='swiss', EventCountry='FRA', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Championnat IDF 2023', Site='Paris', Date='2023.07.11', Round='1.13', White='Laurent, Julien G.', Black='Macon, Arthur', Result='*', WhiteElo='2225', BlackElo='2348', PlyCount='1', EventDate='2023.07.10', EventType='swiss', EventCountry='FRA', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Championnat IDF 2023', Site='Paris', Date='2023.07.11', Round='1.14', White='Rakhmangulova, Anastasiya', Black='Barrish, Daniel', Result='*', ECO='B45', WhiteElo='2347', BlackElo='2221', PlyCount='39', EventDate='2023.07.10', EventType='swiss', EventCountry='FRA', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Championnat IDF 2023', Site='Paris', Date='2023.07.12', Round='2.10', White='Barrish, Daniel', Black='Ternault, Mathieu', Result='*', ECO='A07', WhiteElo='2221', BlackElo='2351', PlyCount='11', EventDate='2023.07.10', EventType='swiss', EventCountry='FRA', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Turkish Ikinci Ligi 2023', Site='Denizli', Date='2023.07.12', Round='6', White='Kartal, Koray', Black='Asgari, Morteza', Result='*', ECO='B51', WhiteElo='1962', BlackElo='2149', PlyCount='19', EventDate='2023.07.07', EventCountry='TUR', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Turkish Ikinci Ligi 2023', Site='Denizli', Date='2023.07.12', Round='6', White='Tahaoglu, Erkin', Black='Albayrak, Abdurrahman Kerem', Result='*', ECO='A48', WhiteElo='1777', PlyCount='23', EventDate='2023.07.07', EventCountry='TUR', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Turkish Ikinci Ligi 2023', Site='Denizli', Date='2023.07.12', Round='6', White='Ergani, Efe', Black='Cekicoglu, Baris', Result='*', ECO='C00', WhiteElo='1707', BlackElo='1666', PlyCount='26', EventDate='2023.07.07', EventCountry='TUR', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Turkish Ikinci Ligi 2023', Site='Denizli', Date='2023.07.12', Round='6', White='Unal, Yusuf Evcim', Black='Demirag, Gokhan', Result='*', ECO='A45', WhiteElo='1638', BlackElo='1901', PlyCount='24', EventDate='2023.07.07', EventCountry='TUR', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Turkish Ikinci Ligi 2023', Site='Denizli', Date='2023.07.12', Round='6', White='Gucer, Gunes', Black='Ekinci, Berkay', Result='*', ECO='D20', WhiteElo='1586', BlackElo='1808', PlyCount='22', EventDate='2023.07.07', EventCountry='TUR', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Turkish Ikinci Ligi 2023', Site='Denizli', Date='2023.07.12', Round='6', White='Dirican, Feride', Black='Sarac, Ayca', Result='*', ECO='B28', WhiteElo='1502', BlackElo='1190', PlyCount='19', EventDate='2023.07.07', EventCountry='TUR', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Turkish Ikinci Ligi 2023', Site='Denizli', Date='2023.07.12', Round='6', White='Uymaz, Suleyman', Black='Kocakose, Omer Melih', Result='*', ECO='D04', WhiteElo='1406', BlackElo='1410', PlyCount='12', EventDate='2023.07.07', EventCountry='TUR', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# Headers(Event='Turkish Ikinci Ligi 2023', Site='Denizli', Date='2023.07.12', Round='6', White='Akbaba, Cinar', Black='Baykara, Mehmet Mert', Result='*', ECO='B07', WhiteElo='1184', BlackElo='1872', PlyCount='17', EventDate='2023.07.07', EventCountry='TUR', SourceTitle='playchess.com', Source='ChessBase', SourceQuality='1')
# ['0-1', '1/2-1/2', '1-0', '*']
